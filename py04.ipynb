# %% [markdown]
# # 판다스 (pandas)

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.0 MB 10.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/11.0 MB 11.2 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 11.4 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.0 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, pandas
#
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-2.3.1 pytz-2025.2

# %%
import numpy as np
import pandas as pd

# %%
# 판다스 Series

data1 = np.arange(1,6)
print(data1)
data2 = pd.Series(data1)
print(data2)
data2.index, data2.values
# Out:
# [1 2 3 4 5]
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# (RangeIndex(start=0, stop=5, step=1), array([1, 2, 3, 4, 5]))

# %%
data3 = pd.Series([11,22,33,44,55])
data3
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# 4    55
# dtype: int64

# %%
dd = {"apple" : 4400, "banana" :3500, "kiwi" : 2000, "orange" : 2100, "mango": 8200 }
data4 = pd.Series(dd)
data4
# Out:
# apple     4400
# banana    3500
# kiwi      2000
# orange    2100
# mango     8200
# dtype: int64

# %%
print(type(data4))
data4.name = "과일 가격표"
data4.index.name = "과일 이름"
data4, data4.index, data4.values
data4
# Out:
# <class 'pandas.core.series.Series'>
# 과일 이름
# apple     4400
# banana    3500
# kiwi      2000
# orange    2100
# mango     8200
# Name: 과일 가격표, dtype: int64

# %%
data2.index = ["aa","bb","cc","ee","dd"] # 개수가 같아야 함
data2 , data2.index, data2.values
# Out:
# (aa    1
#  bb    2
#  cc    3
#  ee    4
#  dd    5
#  dtype: int64,
#  Index(['aa', 'bb', 'cc', 'ee', 'dd'], dtype='object'),
#  array([1, 2, 3, 4, 5]))

# %%
# 판다스 시리즈 데이터 타입
data5 = pd.Series(np.arange(1,7), dtype = "float", index = ["aa","bb","cc","dd","ee","ff"])
data5, data5.shape, data5.size, data5.ndim
# Out:
# (aa    1.0
#  bb    2.0
#  cc    3.0
#  dd    4.0
#  ee    5.0
#  ff    6.0
#  dtype: float64,
#  (6,),
#  6,
#  1)

# %%
# 시리즈 원소에 접근방법
print(data5)
print(data5['dd'])
print(data5.loc['dd'])
print("data5.iloc[3]:",data5.iloc[3] )
# Out:
# aa    1.0
# bb    2.0
# cc    3.0
# dd    4.0
# ee    5.0
# ff    6.0
# dtype: float64
# 4.0
# 4.0
# data5.iloc[3]: 4.0

# %% [markdown]
# ## 데이터프레임 Dataframe

# %%
import pandas as pd
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],index=["a","b","c"], columns=["A","B","c"])
df
# Out:
#    A  B  c
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
num = np.arange(1,10).reshape(3,3)
df = pd.DataFrame(num, index=["a","b","c"], columns=["A","B","c"])
df
# Out:
#    A  B  c
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
dd = {"과일이름":["apple","banana", "kiwi", "melon", "orange", "mango"], 
      "가격": [4400,5000,2500,7200,7700,8100], 
      "개수":[3,8,11,22,3,5]}
df2 = pd.DataFrame(dd)
df2.index = range(1,7)
df2.index.name = "No."
df2
# Out:
#        과일이름    가격  개수
# No.
# 1     apple  4400   3
# 2    banana  5000   8
# 3      kiwi  2500  11
# 4     melon  7200  22
# 5    orange  7700   3
# 6     mango  8100   5

# %%
df2
# Out:
#        과일이름    가격  개수
# No.
# 1     apple  4400   3
# 2    banana  5000   8
# 3      kiwi  2500  11
# 4     melon  7200  22
# 5    orange  7700   3
# 6     mango  8100   5

# %%
df2.columns.name = "imfo"
df2.index.name = ''
df2.columns = ["과일이름", "원가","수량"]
df2
# Out:
#      과일이름    원가  수량
#
# 1   apple  4400   3
# 2  banana  5000   8
# 3    kiwi  2500  11
# 4   melon  7200  22
# 5  orange  7700   3
# 6   mango  8100   5

# %%
df3= pd.DataFrame(df2,columns = ["과일이름", "원가", "품종","할인","수량", "합계"])
df3, df3.dtypes
# Out:
# (     과일이름    원가  품종  할인  수량  합계
#
#  1   apple  4400 NaN NaN   3 NaN
#  2  banana  5000 NaN NaN   8 NaN
#  3    kiwi  2500 NaN NaN  11 NaN
#  4   melon  7200 NaN NaN  22 NaN
#  5  orange  7700 NaN NaN   3 NaN
#  6   mango  8100 NaN NaN   5 NaN,
#  과일이름     object
#  원가        int64
#  품종      float64
#  할인      float64
#  수량        int64
#  합계      float64
#  dtype: object)

# %%
df2.describe()
# Out:
#                 원가         수량
# count     6.000000   6.000000
# mean   5816.666667   8.666667
# std    2206.732124   7.229569
# min    2500.000000   3.000000
# 25%    4550.000000   3.500000
# 50%    6100.000000   6.500000
# 75%    7575.000000  10.250000
# max    8100.000000  22.000000

# %%
df3.loc[:,'품종'] = df3.loc[:,'품종'].astype('object')
df3.loc[:,'품종'] = ['신선한', '궁금한','맛있는','최적의','웰빙','유기농']
df3.loc[:,'할인'] = [0.2,0.3,0.1,0.3,0.2,0.1]
df3
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23180\411737908.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[nan nan nan nan nan nan]' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df3.loc[:,'품종'] = df3.loc[:,'품종'].astype('object')
#      과일이름    원가   품종   할인  수량  합계
#
# 1   apple  4400  신선한  0.2   3 NaN
# 2  banana  5000  궁금한  0.3   8 NaN
# 3    kiwi  2500  맛있는  0.1  11 NaN
# 4   melon  7200  최적의  0.3  22 NaN
# 5  orange  7700   웰빙  0.2   3 NaN
# 6   mango  8100  유기농  0.1   5 NaN

# %%
df3['합계'] = (df3["원가"] * df3["수량"] * (1 - df3["할인"])).astype('int')
df3
# Out:
#      과일이름    원가   품종   할인  수량      합계
#
# 1   apple  4400  신선한  0.2   3   10560
# 2  banana  5000  궁금한  0.3   8   28000
# 3    kiwi  2500  맛있는  0.1  11   24750
# 4   melon  7200  최적의  0.3  22  110880
# 5  orange  7700   웰빙  0.2   3   18480
# 6   mango  8100  유기농  0.1   5   36450

# %%
df3['ETC'] = "-"
df3['Test'] = "test"
print(df3.dtypes)
df3
# Out:
# 과일이름     object
# 원가        int64
# 품종       object
# 할인      float64
# 수량        int64
# 합계        int64
# ETC      object
# Test     object
# dtype: object
#      과일이름    원가   품종   할인  수량      합계 ETC  Test
#
# 1   apple  4400  신선한  0.2   3   10560   -  test
# 2  banana  5000  궁금한  0.3   8   28000   -  test
# 3    kiwi  2500  맛있는  0.1  11   24750   -  test
# 4   melon  7200  최적의  0.3  22  110880   -  test
# 5  orange  7700   웰빙  0.2   3   18480   -  test
# 6   mango  8100  유기농  0.1   5   36450   -  test

# %%
del df3['Test']
df3
# Out:
#      과일이름    원가   품종   할인  수량      합계 ETC
#
# 1   apple  4400  신선한  0.2   3   10560   -
# 2  banana  5000  궁금한  0.3   8   28000   -
# 3    kiwi  2500  맛있는  0.1  11   24750   -
# 4   melon  7200  최적의  0.3  22  110880   -
# 5  orange  7700   웰빙  0.2   3   18480   -
# 6   mango  8100  유기농  0.1   5   36450   -

# %%
ee =pd.Series([1.3,2.2], index=[2,4])
df3['ETC'] = ee
df3 = df3.fillna('')
df3
# Out:
#      과일이름    원가   품종   할인  수량      합계  ETC
#
# 1   apple  4400  신선한  0.2   3   10560
# 2  banana  5000  궁금한  0.3   8   28000  1.3
# 3    kiwi  2500  맛있는  0.1  11   24750
# 4   melon  7200  최적의  0.3  22  110880  2.2
# 5  orange  7700   웰빙  0.2   3   18480
# 6   mango  8100  유기농  0.1   5   36450

# %%
df3['PASS'] = ''
df3
# Out:
#      과일이름    원가   품종   할인  수량      합계  ETC PASS
#
# 1   apple  4400  신선한  0.2   3   10560
# 2  banana  5000  궁금한  0.3   8   28000  1.3
# 3    kiwi  2500  맛있는  0.1  11   24750
# 4   melon  7200  최적의  0.3  22  110880  2.2
# 5  orange  7700   웰빙  0.2   3   18480
# 6   mango  8100  유기농  0.1   5   36450

# %%
pp = np.where(df3['합계']<=30000,'구매각','-')
df3['PASS'] = pp
df3
# Out:
#      과일이름    원가   품종   할인  수량      합계  ETC PASS
#
# 1   apple  4400  신선한  0.2   3   10560       구매각
# 2  banana  5000  궁금한  0.3   8   28000  1.3  구매각
# 3    kiwi  2500  맛있는  0.1  11   24750       구매각
# 4   melon  7200  최적의  0.3  22  110880  2.2    -
# 5  orange  7700   웰빙  0.2   3   18480       구매각
# 6   mango  8100  유기농  0.1   5   36450         -

# %%
# df3.iloc[1,1:4]
# df3.loc[2,:]
df3.loc[df3.loc[:,'과일이름']=='banana','품종':'수량']
# Out:
#     품종   할인  수량
#
# 2  궁금한  0.3   8

# %%
df3.loc[df3.loc[:,'PASS']=='구매각',['과일이름','품종','원가','PASS']]
# Out:
#      과일이름   품종    원가 PASS
#
# 1   apple  신선한  4400  구매각
# 2  banana  궁금한  5000  구매각
# 3    kiwi  맛있는  2500  구매각
# 5  orange   웰빙  7700  구매각

# %%
import pandas as pd

data = {
    "population": [51780, 12580, 144100, 331000],  # 단위: 만명 (예시)
    "GDP": [1_800, 5_000, 14_300, 21_400]         # 단위: 십억 달러 (예시)
}

country = ['korea', 'japan', 'china', 'usa']

df = pd.DataFrame(data, index=countries)
df.index.name = "country"

print(df)
# Out:
#          population    GDP
# country
# korea         51780   1800
# japan         12580   5000
# china        144100  14300
# usa          331000  21400

# %%
import pandas as pd

data = {
    "population": [51780, 12580, 144100, 331000],
    "GDP": [1800, 5000, 14300, 21400]
}

countries = ["korea", "japan", "china", "usa"]

df = pd.DataFrame(data, index=countries)
df.index.name = "country"

# %%
print(df.loc[['korea'], :])
# Out:
#          population   GDP   GDP_per
# country
# korea         51780  1800  0.034762

# %%
# 1인당 GDP 컬럼 추가
df['GDP_per'] = df['GDP'] / df['population']

print(df)
# Out:
#          population    GDP   GDP_per
# country
# korea         51780   1800  0.034762
# japan         12580   5000  0.397456
# china        144100  14300  0.099237
# usa          331000  21400  0.064653
